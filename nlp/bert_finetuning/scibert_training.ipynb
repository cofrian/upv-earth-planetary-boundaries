# %%
import pandas as pd 
import numpy as np
from pathlib import Path

# %%
# Repo root resolved from this notebook's location (nlp/bert_finetuning/).
REPO_ROOT = Path.cwd().parents[1] if Path.cwd().name == "bert_finetuning" else Path.cwd()

path_corpus = REPO_ROOT / "data" / "corpus" / "corpus_1000_clean_enriched.csv"

df = pd.read_csv(path_corpus)

df.head()
# Out:
#          doc_id                                              title  \
# 0  b39624d6c38a  CHAPTER 34 THE ROLE OF HYDROLOGICAL MODELLING ...
# 1  d7b8d727bf7f       Water 2010, 2, 788-814; doi:10.3390/w2040788
# 2  98b2994454de  Final Draft of the original manuscript: Matthi...
# 3  36709684add1  (IJACSA) International Journal of Advanced Com...
# 4  78da21206ecf  Coupled simulations of Greenland Ice Sheetand ...
#
#                                         abstract_raw  \
# 0  and simplify real patterns and processes that ...
# 1  This paper presents an assessment of the cost ...
# 2  Realistic meteorological ﬁelds are a prerequis...
# 3  —The adverse effect of climate change is gradu...
# 4  Recent observations indicate a high sensitivit...
#
#                                        abstract_norm  \
# 0  and simplify real patterns and processes that ...
# 1  This paper presents an assessment of the cost ...
# 2  Realistic meteorological fields are a prerequi...
# ...

# %%
path_pb = REPO_ROOT
